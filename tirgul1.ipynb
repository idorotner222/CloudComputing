# %% [markdown]
# <a href="https://colab.research.google.com/github/idorotner222/CloudComputing/blob/main/tirgul1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello,World")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !ls "/content/drive/My Drive/Colab Notebooks"

# %%
# !pip install numpy

# %%
import time
print(time.ctime())
x=5

# %%
time.sleep(5)
print (time.ctime())
print(x)

# %%
import numpy as np
from matplotlib import pyplot as plt

y = np.random.randn(100)
x = [x for x in range(len(y))]

plt.plot(x, y, '-')
plt.fill_between(x, y, 3, where = (y > 0), facecolor='g', alpha=0.6)

plt.title("Sample Plot")
plt.show()

# %%
# @title update colors {"display-mode":"both"}
colors = "green" # @param ["green","red"]
sleeptime = 3 # @param [5,3]

# %%
print(colors)

# %%
import time
print(time.ctime())
time.sleep(sleeptime)
print(time.ctime())

# %%
#@title Date fields
date_input = '2019-06-03' #@param {type:"date"}
print(date_input)

# %%
#@title Default title text
# %%html
<style>
body {
  background-color: #f2bcca;
}
</style>
color = 'green' #@param ["red", "green", "blue"] print(color)
<svg xmlns="https://www.w3.org/2000/svg" viewBox="0 0 600 400" width="400" height="400">
   <rect x="10" y="00" width="300" height="100" rx="0" style="fill:orange; stroke:black; fill-opacity:1.0" />
   <rect x="10" y="100" width="300" height="100" rx="0" style="fill:white; stroke:black; fill-opacity:1.0;" />
   <rect x="10" y="200" width="300" height="100" rx="0" style="fill:green; stroke:black; fill-opacity:1.0;" />
</svg>

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/אורט בראודה - הנדסת תוכנה/cloud computing')

# %%
# !ls "/content/drive/MyDrive/אורט בראודה - הנדסת תוכנה/cloud computing"

# %%
with open('/content/drive/MyDrive/אורט בראודה - הנדסת תוכנה/cloud computing/1.txt', 'r') as file:
    contents = file.read()
    print(contents)

# %%
# @title Write to new_file.txt
content_to_write = 'This is some example text.' # @param {type:"string"}

with open('/content/drive/MyDrive/אורט בראודה - הנדסת תוכנה/cloud computing/example.txt', 'w') as file:
    file.write(content_to_write)

# %%
with open('1.txt', 'r') as file:
    lines = file.readlines()
    print(lines)
    file.close()

# %%
with open('example.txt', 'r') as file:
    lines = file.readlines()
    print(lines)
    file.close()

# %%
import ipywidgets as widgets
from IPython.display import display
button = widgets.Button(description="Click Me!")
output = widgets.Output()

def on_button_clicked(b):
  # Display the message within the output widget.
  with output:
    with open('1.txt', 'r') as file:
      contents = file.read()
      print(contents)

button.on_click(on_button_clicked)
display(button, output)

# %%
import ipywidgets as widgets
slider = widgets.IntSlider(value=5, max=10)
display(slider)

# %%
# @title Write to new_file.txt
content_to_write = "Ido Rotner, ido.rotner2@gmail.com, cloud computing, https://www.sport5.co.il/ \nShay Gonen" # @param {type:"string"}

with open('/content/drive/MyDrive/אורט בראודה - הנדסת תוכנה/cloud computing/students.txt', 'w') as file:
    file.write(content_to_write)

# %%
# @title שלב 4: עדכון תוכנית אהובה (Append)
# @markdown הריץ תא זה כדי להוסיף את התוכנית האהובה לסטודנט שנבחר.

# פרמטרים מהטופס
favorite_show = "האלופה" # @param {type:"string"}
student_name = "Ido Rotner" # @param {type:"string"}

# הגדרת נתיב הקובץ (זהה לשלבים הקודמים)
file_path = '/content/drive/MyDrive/אורט בראודה - הנדסת תוכנה/cloud computing/students.txt'

# שימוש במצב 'a' כדי להוסיף לסוף הקובץ
# הוספנו "\n" בתחילת המחרוזת כדי להבטיח שהעדכון יירשם בשורה חדשה
with open(file_path, 'a', encoding='utf-8') as file:
    content_to_append = f"\n{student_name}, תוכנית אהובה: {favorite_show}"
    file.write(content_to_append)

print(f"✅ הפרטים נוספו בהצלחה לסוף הקובץ!")
print(f"שורת העדכון: {content_to_append}")
